# %%
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium import webdriver
import openpyxl

fundos = [
    "AAGR11", "AAZQ11", "ABCP11", "AFCR11", "AFHI11", "AFOF11", "AGRX11", "AIEC11", "AJFI11", "ALMI11",
    "ALZC11", "ALZM11", "ALZR11", "AMAZ11", "ANCR11B", "APTO11", "APXM11", "APXR11", "APXU11", "AQLL11",
    "ARCT11", "ARFI11B", "AROA11", "ARRI11", "ARXD11", "ASMT11", "ASRF11", "ATCR11", "ATSA11", "ATSA11B",
    "ATWN11", "AURB11", "AZPL11", "BARI11", "BBFI11B", "BBFO11", "BBGO11", "BBIG11", "BBIM11", "BBPO11",
    "BBRC11", "BBVJ11", "BCFF11", "BCIA11", "BCRI11", "BDIF11", "BETW11", "BICE11", "BICR11", "BIDB11",
    "BIME11", "BIPD11", "BIPE11", "BLCA11", "BLCP11", "BLMC11", "BLMG11", "BLMO11", "BLMR11", "BLOG11",
    "BLUR11", "BMII11", "BMLC11", "BMLC11B", "BNFS11", "BODB11", "BPFF11", "BPLC11", "BPML11", "BPRP11",
    "BRCO11", "BRCR11", "BREV11", "BRFT11", "BRHT11B", "BRIM11", "BRIP11", "BRIX11", "BRLA11", "BROF11",
    "BRSE11", "BRZD11", "BTAG11", "BTAL11", "BTCI11", "BTCR11", "BTHI11", "BTLG11", "BTML11", "BTRA11",
    "BTSG11", "BTSI11", "BTWR11", "BTYU11", "BVAR11", "BZEL11", "BZLI11", "CACR11", "CAFE11", "CARE11",
    "CBOP11", "CCLB11", "CCME11", "CCRF11", "CCVA11", "CDII11", "CENU11", "CEOC11", "CFHI11", "CFII11",
    "CIXM11", "CIXR11", "CJCT11", "CJFI11", "CLIN11", "CNES11", "COPP11", "CORM11", "CPFF11", "CPFO11",
    "CPLG11", "CPOF11", "CPSH11", "CPTI11", "CPTR11", "CPTS11", "CRAA11", "CRFF11", "CSMC11", "CTEM11",
    "CTNP11", "CTXT11", "CVBI11", "CVPR11", "CXAG11", "CXAG11", "CXCE11B", "CXCI11", "CXCO11", "CXRI11",
    "CXTL11", "CYCR11", "CYLD11", "DAMA11", "DAMT11B", "DCRA11", "DEVA11", "DLMT11", "DMAC11", "DOMC11",
    "DOVL11B", "DPRO11", "DRIT11B", "DVFF11", "DVLP11", "EDFO11B", "EDGA11", "EDGE11", "EGAF11", "EGDB11",
    "EGYR11", "ELDO11B", "EMET11", "EQIN11", "EQIR11", "ERCR11", "ERPA11", "ESTQ11", "EURO11", "EVBI11",
    "EXES11", "FAED11", "FAGL11", "FAMB11B", "FAOE11", "FARU11", "FATN11", "FCFL11", "FEXC11", "FGAA11",
    "FGPM11", "FIGS11", "FIIB11", "FIIP11B", "FINF11", "FISC11", "FISD11", "FIVN11", "FIXX11", "FLCR11",
    "FLEM11", "FLFL11", "FLMA11", "FLNR11", "FLRP11", "FMOF11", "FPAB11", "FPNG11", "FRHY11", "FTCE11B",
    "FTRE11", "FVBI11", "FVPQ11", "FZDA11", "FZDB11", "GALG11", "GAME11", "GARE11", "GCFF11", "GCOI11",
    "GCRA11", "GCRI11", "GESE11B", "GGRC11", "GLOG11", "GRLV11", "GRUL11", "GRWA11", "GSFI11", "GTLG11",
    "GTWR11", "GURB11", "GVBI11", "GZIT11", "HAAA11", "HABT11", "HBCR11", "HBRH11", "HBTT11", "HCHG11",
    "HCPR11", "HCRA11", "HCRI11", "HCST11", "HCTR11", "HDEL11", "HDOF11", "HFOF11", "HGAG11", "HGBL11",
    "HGBS11", "HGCR11", "HGFF11", "HGIC11", "HGLG11", "HGPO11", "HGRE11", "HGRS11", "HGRU11", "HILG11",
    "HLMB11", "HLOG11", "HMOC11", "HOFC11", "HOMS11", "HOSI11", "HPDP11", "HRDF11", "HREC11", "HRES11",
    "HSAF11", "HSLG11", "HSML11", "HSRE11", "HTMX11", "HUCG11", "HUSC11", "HUSI11", "IAAG11", "IAGR11",
    "IBBP11", "IBCR11", "IBFF11", "ICNE11", "ICRI11", "IDFI11", "IDGO11", "IDGR11", "IDUA11", "IFID11",
    "IFIE11", "IFRA11", "IFRI11", "IMOV11", "INDE11", "INFA11", "INFB11", "IRDM11", "IRIM11", "ISCJ11",
    "ITIP11", "ITIT11", "ITRI11", "JASC11", "JBFO11", "JCCJ11", "JCDA11", "JCDB11", "JCIN11", "JFLL11",
    "JGPX11", "JMBI11", "JPPA11", "JPPC11", "JRDM11", "JSAF11", "JSCR11", "JSRE11", "JTPR11", "JURO11",
    "KCRE11", "KDIF11", "KDOL11", "KEVE11", "KFEN11", "KFOF11", "KINP11", "KISU11", "KIVO11", "KLOG11",
    "KNCA11", "KNCR11", "KNHF11", "KNHY11", "KNIP11", "KNPR11", "KNRE11", "KNRI11", "KNSC11", "KNUQ11",
    "KOPA11", "KOPI11", "KORE11", "KRES11", "LAFI11", "LASC11", "LATR11B", "LAVF11", "LFTT11", "LGCP11",
    "LIFE11", "LKDV11", "LLAO11", "LOFT11", "LOFT11B", "LPLP11", "LRDI11", "LRED11", "LSAG11", "LSOI11",
    "LSPA11", "LTMT11", "LUGG11", "LVBI11", "MALL11", "MANA11", "MATV11", "MAVC11", "MAXR11", "MBRF11",
    "MCCI11", "MCEM11", "MCHF11", "MCHY11", "MFAI11", "MFCR11", "MFII11", "MGCR11", "MGFF11", "MGHT11",
    "MGIM11", "MGLC11", "MGLG11", "MGRI11", "MINT11", "MMPD11", "MMVE11", "MOFF11", "MORC11", "MORE11",
    "MTOF11", "MTRS11", "MVFI11", "MXRF11", "MYDW11", "N4V111", "NAGR11", "NAVT11", "NCHB11", "NCRA11",
    "NCRI11", "NEWL11", "NEWU11", "NEXG11", "NIVT11", "NPAR11", "NSLU11", "NUIF11", "NVHO11", "NVIF11B",
    "OBAL11", "OCRE11", "OGHY11", "OGIN11", "OIAG11", "ONDV11", "ONEF11", "OPTM11", "ORPD11", "OUCY11",
    "OUFF11", "OUJP11", "OULG11", "OURE11", "PABY11", "PATA11", "PATB11", "PATC11", "PATL11", "PBLV11",
    "PCAS11", "PEMA11", "PLCA11", "PLCR11", "PLOG11", "PLRI11", "PMFO11", "PMIS11", "PNCR11", "PNDL11",
    "PNLM11", "PNLN11", "PNPR11", "PNRC11", "PORD11", "PQAG11", "PQDP11", "PRSN11B", "PRSV11", "PRTS11",
    "PRZS11", "PULV11", "PURB11", "PVBI11", "QAGR11", "QAMI11", "QIFF11", "QIRI11", "QTZD11", "RBBV11",
    "RBCB11", "RBCO11", "RBDS11", "RBED11", "RBFF11", "RBGS11", "RBHG11", "RBHY11", "RBIF11", "RBIR11",
    "RBIV11", "RBLG11", "RBOP11", "RBRD11", "RBRF11", "RBRI11", "RBRL11", "RBRM11", "RBRP11", "RBRR11",
    "RBRS11", "RBRX11", "RBRY11", "RBTS11", "RBVA11", "RBVO11", "RCFA11", "RCFF11", "RCKF11", "RCRB11",
    "RCRI11B", "RDCI11", "RDES11", "RDLI11", "RDLS11", "RDPD11", "RECR11", "RECT11", "RECX11", "REIT11",
    "RELG11", "RENV11", "REON11", "RFOF11", "RIFF11", "RINV11", "RMAI11", "RNDP11", "RNGO11", "ROOF11",
    "RPRI11", "RRCI11", "RSPD11", "RTEL11", "RURA11", "RVBI11", "RZAG11", "RZAK11", "RZAT11", "RZDM11",
    "RZEO11", "RZTR11", "RZZI11", "SAAG11", "SACL11", "SADI11", "SAIC11B", "SALI11", "SAPI11", "SARE11",
    "SBCL11", "SCPF11", "SDIL11", "SDIP11", "SEED11", "SEQR11", "SEQR11", "SFND11", "SHDP11B", "SHOP11",
    "SHPH11", "SHSO11", "SIGR11", "SJAU11", "SLDZ11", "SMRE11", "SNAG11", "SNCI11", "SNEL11", "SNFF11",
    "SNFZ11", "SNID11", "SNLG11", "SNME11", "SOLR11", "SPAF11", "SPDE11", "SPGM11", "SPMO11", "SPTW11",
    "SPVJ11", "SPXC11", "SPXG11", "SPXL11", "SPXS11", "SRVD11", "STMB11", "STRX11", "TBOF11", "TCIN11",
    "TCPF11", "TELD11", "TELF11", "TELM11", "TEPP11", "TGAR11", "THRA11", "TJKB11", "TMPS11", "TORD11",
    "TORM13", "TOUR11", "TRBL11", "TRNT11", "TRXB11", "TRXF11", "TSER11", "TSNC11", "TSNM11", "TVRI11",
    "UBSR11", "UMED11", "URHF11", "URPR11", "VANG11", "VCHG11", "VCJR11", "VCRA11", "VCRI11", "VCRR11",
    "VCTH11", "VDSV11", "VERE11", "VGHF11", "VGIA11", "VGII11", "VGIP11", "VGIR11", "VGRI11", "VIDS11",
    "VIFI11", "VILG11", "VINO11", "VISC11", "VIUR11", "VJFD11", "VLIQ11", "VLJS11", "VLOL11", "VOTS11",
    "VPSI11", "VRTA11", "VRTM11", "VSEC11", "VSHO11", "VSLH11", "VTLT11", "VTPA11", "VTPL11", "VTVI11",
    "VTXI11", "VVCO11", "VVCR11", "VVMR11", "VVPR11", "VVRI11", "VXXV11", "WHGR11", "WPLZ11", "WSEC11",
    "WTSP11B", "WVSC11", "XBXO11", "XPCA11", "XPCI11", "XPCM11", "XPHT11", "XPID11", "XPIN11", "XPLG11",
    "XPML11", "XPPR11", "XPSF11", "XTED11", "YCHY11", "YEES11", "YUFI11", "ZAGH11", "ZAVC11", "ZAVI11",
    "ZIFI11"
]


url = 'https://statusinvest.com.br/fundos-imobiliarios/'

try:
    nome_do_arquivo = openpyxl.load_workbook('C:\ARQUIVOS\Documentos\Analise\statusinvest_fiis.xlsx')
except FileNotFoundError:
    # Se o arquivo não existir, você pode criar um novo workbook
    nome_do_arquivo = openpyxl.Workbook()

# Verificar se a planilha existe
if 'statusinvest_fiis' in nome_do_arquivo.sheetnames:
    dados = nome_do_arquivo['statusinvest_fiis']
else:
    # Se a planilha não existir, crie-a
    dados = nome_do_arquivo.create_sheet('statusinvest_fiis')

urls_fiis = []

# Configurar o WebDriver
chrome_op = Options()
chrome_op.headless = True
google = webdriver.Chrome(options=chrome_op)

# Adicionar cabeçalhos à planilha, se não existirem
if dados.max_row == 1:
    dados.append([
        'Ticker', 'Público Alvo', 'Tipo de Fii', 'Administrador', 'Ultimo Data Pagamento',
        'Último Rend. (R$)', 'Último Rend. (%)', 'Último Data Base', 'Último Cota base',
        'Próximo Data Pagamento', 'Próximo Rend. (R$)', 'Próximo Rend. (%)', 'Próximo Data Base',
        'Próximo Cota base', 'Rend. Méd. 12m (R$)', 'Rend. Méd. 12m (%)', 'Patrimônio/Cota',
        'Cotação/VP', 'N° negócios/mês', 'Partic. IFIX', 'Número Cotistas', 'Patrimônio', 'Min 52 semanas',
        'Max 52 semanas', 'Min Mês', 'Max Mês', 'Valorizacao 12m', 'Valorizacao Mês'
    ])

# Percorrer os fundos e coletar os dados
for fiis in fundos:
    urls_fiis = url + fiis
    google.get(urls_fiis)
    time.sleep(5)
    # Coletar os dados da página
    try:
        publico_alvo = google.find_element(By.XPATH, '/html/body/main/div[3]/div/div/div[4]/div/div[3]/div/div/div/strong').text
        tipo_fii = google.find_element(By.XPATH, '/html/body/main/div[3]/div/div/div[4]/div/div[1]/div/div/div/a/strong').text
        administrador = google.find_element(By.XPATH, '/html/body/main/div[3]/div/div/div[3]/div/div[2]/div[1]/div/strong').text
        
        datapagamento_ultimo = google.find_element(By.XPATH, '/html/body/main/div[2]/div[7]/div[2]/div/div[2]/div[2]/div[2]/div/b').text
        rendimento_ultimo = google.find_element(By.XPATH, '/html/body/main/div[2]/div[7]/div[2]/div/div[1]/strong').text
        rendimentoP_ultimo = google.find_element(By.XPATH, '/html/body/main/div[2]/div[7]/div[2]/div/div[2]/div[1]/div[1]/div/b').text
        database_ultimo = google.find_element(By.XPATH, '/html/body/main/div[2]/div[7]/div[2]/div/div[2]/div[2]/div[1]/div/b').text        
        cotacaobase_ultimo = google.find_element(By.XPATH, '/html/body/main/div[2]/div[7]/div[2]/div/div[2]/div[1]/div[2]/div/b').text

        datapagamento_proximo = google.find_element(By.XPATH, '/html/body/main/div[2]/div[7]/div[3]/div/div[2]/div[2]/div[2]/div/b').text
        rendimento_proximo = google.find_element(By.XPATH, '/html/body/main/div[2]/div[7]/div[3]/div/div[1]/strong').text
        rendimentoP_proximo = google.find_element(By.XPATH, '/html/body/main/div[2]/div[7]/div[3]/div/div[2]/div[1]/div[1]/div/b').text
        database_proximo = google.find_element(By.XPATH, '/html/body/main/div[2]/div[7]/div[3]/div/div[2]/div[2]/div[1]/div/b').text        
        cotacaobase_proximo = google.find_element(By.XPATH, '/html/body/main/div[2]/div[7]/div[3]/div/div[2]/div[1]/div[2]/div/b').text

        rendimentomedio12_reais = google.find_element(By.XPATH, '/html/body/main/div[2]/div[1]/div[4]/div/div[2]/div/span[2]').text        
        rendimentomedio12_porcentagem = google.find_element(By.XPATH, '/html/body/main/div[2]/div[1]/div[4]/div/div[1]/strong').text

        patrimonio_cota = google.find_element(By.XPATH, '/html/body/main/div[2]/div[5]/div/div[1]/div/div[1]/strong').text        
        cotacao_vp = google.find_element(By.XPATH, '/html/body/main/div[2]/div[5]/div/div[2]/div/div[1]/strong').text

        nnegocio_mes = google.find_element(By.XPATH, '/html/body/main/div[2]/div[7]/div[1]/div/div/div/div[2]/div[1]/span').text        
        participacao_ifix = google.find_element(By.XPATH, '/html/body/main/div[2]/div[6]/div/div/div[4]/div/a/div/div/strong').text
        nro_cotistas = google.find_element(By.XPATH, '/html/body/main/div[2]/div[5]/div/div[6]/div/div[1]/strong').text
        patrimonio = google.find_element(By.XPATH, '/html/body/main/div[2]/div[5]/div/div[1]/div/div[2]/span[2]').text

        min_52semanas = google.find_element(By.XPATH, '/html/body/main/div[2]/div[1]/div[2]/div/div[1]/strong').text        
        max_52semanas = google.find_element(By.XPATH, '/html/body/main/div[2]/div[1]/div[3]/div/div[1]/strong').text
        min_mes = google.find_element(By.XPATH, '/html/body/main/div[2]/div[1]/div[2]/div/div[2]/div/span[2]').text
        max_mes = google.find_element(By.XPATH, '/html/body/main/div[2]/div[1]/div[3]/div/div[2]/div/span[2]').text
        valoriz_12m = google.find_element(By.XPATH, '/html/body/main/div[2]/div[1]/div[5]/div/div[1]/strong').text
        valoriz_mes = google.find_element(By.XPATH, '/html/body/main/div[2]/div[1]/div[5]/div/div[2]/div/span[2]/b').text

        # Adicionar dados coletados à planilha
        dados.append([
            fiis, publico_alvo, tipo_fii, administrador, datapagamento_ultimo,
            rendimento_ultimo, rendimentoP_ultimo, database_ultimo, cotacaobase_ultimo,
            datapagamento_proximo, rendimento_proximo, rendimentoP_proximo, database_proximo,
            cotacaobase_proximo, rendimentomedio12_reais, rendimentomedio12_porcentagem,
            patrimonio_cota, cotacao_vp, nnegocio_mes, participacao_ifix, nro_cotistas, patrimonio,
            min_52semanas, max_52semanas, min_mes, max_mes, valoriz_12m, valoriz_mes
        ])
    
    except Exception as e:
        print(f"Erro ao coletar e adicionar dados para {fiis}: {e}")
        continue

# Formatar os dados nas colunas específicas
for row in dados.iter_rows(min_row=2, min_col=6, max_col=27):
    for cell in row:
        if isinstance(cell.value, str):
            # Remover caracteres indesejados
            value = cell.value.replace('R$', '').replace('.0', '').replace('.', '').replace('%', '').replace(',', '.')
            try:
                cell.value = float(value)
            except ValueError:
                cell.value = None  # Se não for possível converter para float, deixe a célula em branco

# Fechar o navegador após o loop
google.quit()

# Salvar o arquivo Excel
nome_do_arquivo.save(r'C:\ARQUIVOS\Documentos\Analise\statusinvest_fiis.xlsx')
# Out:
# Erro ao coletar e adicionar dados para AAGR11: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/main/div[3]/div/div/div[4]/div/div[3]/div/div/div/strong"}
#   (Session info: chrome=128.0.6613.85); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF677A8B632+29090]
# 	(No symbol) [0x00007FF6779FE6E9]
# 	(No symbol) [0x00007FF6778BB1CA]
# 	(No symbol) [0x00007FF67790EFD7]
# 	(No symbol) [0x00007FF67790F22C]
# 	(No symbol) [0x00007FF6779597F7]
# 	(No symbol) [0x00007FF67793672F]
# 	(No symbol) [0x00007FF6779565D9]
# 	(No symbol) [0x00007FF677936493]
# 	(No symbol) [0x00007FF6779009B1]
# 	(No symbol) [0x00007FF677901B11]
# 	GetHandleVerifier [0x00007FF677DA881D+3294093]
# 	GetHandleVerifier [0x00007FF677DF4403+3604339]
# 	GetHandleVerifier [0x00007FF677DEA2C7+3563063]
# ...
